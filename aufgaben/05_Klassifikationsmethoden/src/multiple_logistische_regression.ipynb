# %% [markdown]
# ### Multiple logistische Regression: Beispielrechnung

# %%
import math

p_x = math.exp()
#b0 intercept
#b1 balance 
#b2 income
#b3 student
#Ergebnis: default rate ist höher, wenn es kein Student ist
